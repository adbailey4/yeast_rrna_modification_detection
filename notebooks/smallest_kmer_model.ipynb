# %% [markdown]
# ## Create Model
# * Create 5mer, 6mer and 7mer models

# %%
from signalalign.hiddenMarkovModel import HmmModel
import os 

def create_rrna_model(original_rna_model, output_dir, noise=0, new_variants = "abc",
                     replacement_bases = "AAA"):
    alphabet = "ACGT"
    if noise > 0:  
        tmp_rna_model = os.path.join(output_dir, "rna_r94_5mer_{}_noise_"+str(noise)+".model")
    else:
        tmp_rna_model = os.path.join(output_dir, "rna_r94_5mer_{}.model")

    current_model_path = original_rna_model
    for i, (variant, rep_base) in enumerate(zip(new_variants, replacement_bases)):
        alphabet += variant
        rna_model = HmmModel(current_model_path, rna=True)
        print(alphabet)
        rna_model.write_new_model(tmp_rna_model.format(alphabet), alphabet, rep_base,  noise=noise)
        if i > 0:
            os.remove(current_model_path)
        current_model_path = tmp_rna_model.format(alphabet)

# %%
original_rna_model = "small_model/testModelR9p4_5mer_acgt_RNA_180mv.model"
output_dir = "small_model"
create_rrna_model(original_rna_model, output_dir, noise=0, new_variants = "abc", replacement_bases = "AAA")
# Out:
# ACGTa
# ACGTab
# ACGTabc
# /Users/andrewbailey/CLionProjects/signalAlign/src/signalalign/hiddenMarkovModel.py:211: RuntimeWarning: invalid value encountered in double_scalars
#   self.transitions_expectations[i + to_state] = self.transitions_expectations[i + to_state] / j

# %% [markdown]
# ## Smallest Model
#
# Using the same modification for each distribution creates some overlapping kmer distributions which, in aggregate may give us a better picture of the underlying expected current signal. However, when there are only a few kmers contributing, it usually gives bimodal distributions that do not model any of the position's kmer distributions well. So, I want to create a model, specific to the 18S and 25S S.cer rRNA's that has the smallest alphabet so that each position has a set of unique kmers covering that position.
#
# Hopefully this is smaller than the 21 letter alphabet I am using now
#
# 1) Get kmers for each position
# 2) Find overlapping kmers
# 3) the max set of overlapping kmers is the max number of extra characters I need

# %%
import numpy as np
import pandas as pd
from rrna_analysis.kmer_pos_mapping import KmerPosMapping, get_kmers_from_seq, get_covered_kmers, get_kmer_permutations
from py3helpers.seq_tools import ReferenceHandler
from collections import namedtuple, defaultdict
from signalalign.utils.sequenceTools import CustomAmbiguityPositions, reverse_complement
import itertools
import operator
from itertools import zip_longest

# %%
mods_csv = "small_model/mod_file.csv"
reference = "../training/reference/yeast_25S_18S.fa"
alt_c_positions = "small_model/yeast_18S_25S_variants.positions"
# positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/yeast_18S_25S_variants.positions"
kpm = KmerPosMapping(reference, alt_c_positions, mods_csv)
rh = ReferenceHandler(reference)

# %%
positions_data = CustomAmbiguityPositions.parseAmbiguityFile(alt_c_positions)

# %%
def get_mod_positions(mods_csv, k=5):
    mods_data = KmerPosMapping.read_in_mod_data(mods_csv)
    mod_positions = {}
    grouped_positions = {}
    for i, data in mods_data.groupby(["contig", "strand"]):
        contig = i[0]
        strand = i[1]
    #     print(data)
        mod_positions[contig+strand] = data["reference_index"].values
        values = sorted(data["reference_index"].values)
        recent = values[0]
        groups = []
        group = [recent]
        for x in values[1:]:
            if x - recent <= k:
                group.append(x)
            else:
                groups.append(group)
                group = [x]
            recent = x
        grouped_positions[contig+strand] = groups
    return mod_positions, grouped_positions

# %%
def get_list_full_sequence(rh, positions_data, edit=True):
    full_sequence = {}
    for i, data in positions_data.groupby(["contig", "strand"]):
        contig = i[0]
        strand = i[1]
        sequence = rh.get_sequence(contig, None, None)
    #     sequence = self.ref_handler.get_sequence(contig, None, None)
        if strand == "-":
            sequence = rc.complement(sequence)
        list_seq = list(sequence)
        if edit:
            for i, row in data.iterrows():
                assert list_seq[row.position] == row.change_from, f"ref base:{list_seq[row.position]} != position change_from:{row.change_from}"             
                list_seq[row.position] = row.change_to
        full_sequence[contig+strand] = list_seq
    return full_sequence

# %%
def get_kmers_from_list(sequence, index, k, rna):
    sub_seq = sequence[index-k+1:index+k]
    if rna:
        sub_seq = sub_seq[::-1]
    kmers = get_kmer_permutations(sub_seq)
    all_kmers = []
    for x in kmers:
        all_kmers.append(get_kmers_from_seq(x, k))
    all_kmers = [set(x) for x in zip(*all_kmers)]
    if rna:
        all_kmers = all_kmers[::-1]
    return all_kmers

# %%
def get_kmers_from_full_sequence(full_sequence, mod_positions, k=5, rna=True):
    contig_strand_position_kmers = {}
    for contig_strand, ref_indices in mod_positions.items():
        position_kmers = {}
        contig_sequence = full_sequence[contig_strand]
        for index in ref_indices:
            all_kmers = get_kmers_from_list(contig_sequence, index, k, rna)
            position_kmers[str(index)] = all_kmers
        contig_strand_position_kmers[contig_strand] = position_kmers
    return contig_strand_position_kmers

# %%
def get_expected_total(group, k=5):
    total = 0
    curr_window = []
    prev_min = group[0]
    for index in range(group[0]-k+1, group[-1]+1):
        if index+(k-1) in group:
            curr_window.append(index+(k-1))
        if len(curr_window) > 0 and index > curr_window[0]:
            curr_window.pop(0)
        kmers = 2**len(curr_window)
        total += kmers
#         print(index, kmers, curr_window)
    return total

# %%
def get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions, k=5):
    contig_strand_group_kmers = {}
    seen_kmers = {}
    for contig_strand, position_kmers in contig_strand_position_kmers.items():
        gp = grouped_positions[contig_strand]
        group_kmers_list = []
        for group in gp:
    #         print("NEW GROUP", group)
            group_kmers = []
    #         total = 0
            for index in group:
    #             list_of_pos = list(itertools.chain.from_iterable([list(x) for x in position_kmers[str(index)]]))
    #             total += len(list_of_pos)
                group_kmers.extend(set.union(*position_kmers[str(index)]))
            group_kmers = set(group_kmers)
            expected_total = get_expected_total(group, k=k)
    #         print(len(group), group)
    #         print(expected_total, len(group_kmers), len(set(group_kmers)))
    #             print(group_kmers)
            assert expected_total == len(group_kmers), f"expected_total != len(group_kmers), {expected_total} != {len(group_kmers)}"
            group_kmers_list.append(group_kmers)
        contig_strand_group_kmers[contig_strand] = group_kmers_list
    return contig_strand_group_kmers

# %%
def get_fix_positions(contig_strand_group_kmers):
    all_kmers_set = set()
    for cstrand in contig_strand_group_kmers.keys():
        all_kmers_set |= set.union(*contig_strand_group_kmers[cstrand])
    all_kmers_dict = { key : [] for key in all_kmers_set }
    fix_positions = defaultdict(list)
    for cstrand in contig_strand_group_kmers.keys():
        for i, group in enumerate(contig_strand_group_kmers[cstrand]):
            for kmer in group:
                all_kmers_dict[kmer].append(cstrand+str(i))
                if len(all_kmers_dict[kmer]) > 1:
                    fix_positions[cstrand+str(i)] += [kmer]
    return fix_positions

# %%
def get_max_pos_max_len(fix_positions, skip=0):
    max_pos = -1
    max_len = -1
    prev_bests = []
    for pos, k_list in fix_positions.items():
        k_list_len = len(k_list)
        if k_list_len > max_len:
            max_len = k_list_len
            max_pos = pos
            prev_bests.insert(0, [max_pos, max_len])
    if skip >= len(prev_bests):
        max_pos = prev_bests[-1][0]
        max_len = prev_bests[-1][1]
        over = True
    else:
        max_pos = prev_bests[skip][0]
        max_len = prev_bests[skip][1]
        over = False

    return max_pos, max_len, over

# %%
def get_change_base_index(max_pos, fix_positions, grouped_positions, contig_strand_position_kmers, rna=True, k=5, skip=0):
    contig_strand = max_pos[:8]
    pos = int(max_pos[8:])
    kmers = set(fix_positions[max_pos])
#     print(grouped_positions)
#     print(contig_strand)
#     print(grouped_positions[contig_strand])
#     print(max_pos, pos, len(grouped_positions[contig_strand]))
    target_positions = grouped_positions[contig_strand][pos]
    best_pos = None
    best_pos_index = None
    best_kmers = None
    curr_max = 0
    for x in target_positions:
        kmer_sets = contig_strand_position_kmers[contig_strand][str(x)]
        for i, kmer_set in enumerate(kmer_sets):
            overlap_kmers = kmers & kmer_set
            n_kmers = len(overlap_kmers)
            if n_kmers > curr_max:
                curr_max = n_kmers
                best_pos = x
                best_pos_index = i
                best_kmers = overlap_kmers
#     print(best_pos, best_pos_index, best_kmers)
    sub_pos = None
    canonical = {"A", "T", "G", "C"}
    sub_pos_list = []
    for i, x in enumerate(zip_longest(*best_kmers)):
        bases = set(x)
        canonical & bases
        n_bases = len(set(x))
        if n_bases == 1 and len(canonical & bases) == 1:
            sub_pos = i
            sub_pos_list.insert(0, sub_pos)
    
    if skip >= len(sub_pos_list):
        sub_pos = sub_pos_list[-1]
        over = True
    else:
        sub_pos = sub_pos_list[skip]
        over = False
    if rna:
        sub_index = k-sub_pos-1
    change_base_index = (best_pos - k+1) + best_pos_index + sub_index
    return change_base_index, over

# %%
def get_kmer_mapping(og_sequence, contig_strand_position_kmers, k=5, rna=True):
    kmer_mapping = []
    for contig_strand, pos_kmer_map in contig_strand_position_kmers.items():
        for pos, kmer_list in pos_kmer_map.items():
    #         print(contig_strand, pos, kmer_list)
            index = int(pos)
            curr_kmers = get_kmers_from_list(og_sequence[contig_strand], index, k, rna)
    #         print(curr_kmers)
            for kmer_pair in zip(curr_kmers, kmer_list):
                k1 = list(kmer_pair[0])[0]
                k2 = list(kmer_pair[1])
    #             print(k1, k2)
                kmer_mapping.append([k1, k2])
    return kmer_mapping

# %%
def create_efficient_positions_file(reference, ambig_positions, mods_csv, output_path, k=5, rna=True):
    rh = ReferenceHandler(reference)
    mod_positions, grouped_positions = get_mod_positions(mods_csv, k=k)
    positions_data = CustomAmbiguityPositions.parseAmbiguityFile(ambig_positions)
    positions_data.loc[:, "change_to"] = "ab"
    # positions_data = CustomAmbiguityPositions.parseAmbiguityFile(path)
    full_sequence = get_list_full_sequence(rh, positions_data)

    fix_positions = [1, 1]
    iterration = 0
    kmer_mapping = []

    pos_skip = 0
    base_skip = 0
    while len(fix_positions) > 0 and iterration < 1000:
        print("ANOTHER ITER", len(fix_positions))
        contig_strand_position_kmers = get_kmers_from_full_sequence(full_sequence, mod_positions, k=k, rna=rna)
        contig_strand_group_kmers = get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions=grouped_positions, k=k)
        fix_positions = get_fix_positions(contig_strand_group_kmers)
        if len(fix_positions) == 0:
            break
        max_pos, max_len, pos_over = get_max_pos_max_len(fix_positions, skip=pos_skip)
        change_base_index, base_over = get_change_base_index(max_pos, fix_positions, grouped_positions, contig_strand_position_kmers, k=k, rna=rna, skip=base_skip)            


        contig_strand = max_pos[:8]
        contig = max_pos[:7]
        position = change_base_index
        strand = max_pos[7]
        change_from = full_sequence[contig_strand][change_base_index]
        change_to = "c"

        try:
            full_sequence[contig_strand][change_base_index] = change_to
            contig_strand_position_kmers = get_kmers_from_full_sequence(full_sequence, mod_positions, k=k, rna=rna)
            contig_strand_group_kmers = get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions=grouped_positions, k=k)
    #  will not run if causes error

            new_row = {"contig": max_pos[:7],
               "position": change_base_index,
               "strand": max_pos[7],
               "change_from": change_from,
               "change_to": change_to}
            positions_data = positions_data.append(new_row, ignore_index=True)
            print("PASS", max_pos, change_base_index, pos_skip, base_skip)
            fix_positions = get_fix_positions(contig_strand_group_kmers)
            if len(fix_positions) == 0:
                print("DONE")


        except AssertionError:
            full_sequence[contig_strand][change_base_index] = change_from
            if pos_over:
                base_skip += 1
            if not pos_over:
                pos_skip += 1
            if pos_over and base_over:
                raise AssertionError("ERROR", contig_strand, change_base_index, pos_skip, base_skip)            
            print("SKIPPING", contig_strand, change_base_index, pos_skip, base_skip)


        iterration += 1
    positions_data.to_csv(output_path, sep="\t", header=False, index=False)
    #     get kmer mapping
    og_sequence = get_list_full_sequence(rh, positions_data, edit=False)
    kmer_mapping = get_kmer_mapping(og_sequence, contig_strand_position_kmers, k=k, rna=rna)

    return kmer_mapping

# %%
def edit_model_with_kmer_mapping(model, kmer_mapping, rna=True):
    rna_model = HmmModel(model, rna=rna)
    for k, change in kmer_mapping:
        normal_mean, normal_sd = rna_model.get_event_mean_gaussian_parameters(k)
        for k2 in change:
            rna_model.set_kmer_event_mean_params(k2, normal_mean, normal_sd)
    rna_model.normalized = True
    rna_model.write(model)

# %%
mods_csv = "small_model/mod_file.csv"
reference = "../training/reference/yeast_25S_18S.fa"
alt_c_positions = "small_model/yeast_18S_25S_variants.positions"
output_path = "small_model/small_model_yeast_18S_25S_variants.positions"
k=5
rna=True
kmer_mapping = create_efficient_positions_file(reference, alt_c_positions, mods_csv, output_path, k=k, rna=rna)
rna_model = "small_model/rna_r94_5mer_ACGTabc.model"
edit_model_with_kmer_mapping(rna_model, kmer_mapping, rna=rna)
# Out:
# ANOTHER ITER 2
# PASS RDN25-1+45 2944 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2129 0 0
# ANOTHER ITER 39
# PASS RDN25-1+26 2260 0 0
# ANOTHER ITER 39
# PASS RDN25-1+45 2946 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2130 0 0
# ANOTHER ITER 39
# PASS RDN25-1+22 2137 0 0
# ANOTHER ITER 39
# PASS RDN25-1+32 2417 0 0
# ANOTHER ITER 39
# PASS RDN25-1+32 2418 0 0
# ANOTHER ITER 39
# PASS RDN25-1+34 2629 0 0
# ANOTHER ITER 39
# PASS RDN18-1+4 206 0 0
# ANOTHER ITER 39
# PASS RDN18-1+27 1410 0 0
# ANOTHER ITER 39
# PASS RDN18-1+29 1573 0 0
# ANOTHER ITER 39
# PASS RDN25-1+2 774 0 0
# ANOTHER ITER 39
# PASS RDN25-1+11 982 0 0
# ANOTHER ITER 39
# PASS RDN25-1+14 1049 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2131 0 0
# ANOTHER ITER 38
# PASS RDN25-1+22 2139 0 0
# ANOTHER ITER 38
# PASS RDN25-1+22 2140 0 0
# ANOTHER ITER 37
# PASS RDN25-1+31 2347 0 0
# ANOTHER ITER 36
# PASS RDN25-1+33 2617 0 0
# ANOTHER ITER 36
# PASS RDN25-1+34 2632 0 0
# ANOTHER ITER 36
# PASS RDN25-1+34 2634 0 0
# ANOTHER ITER 35
# PASS RDN25-1+37 2730 0 0
# ANOTHER ITER 35
# PASS RDN25-1+39 2811 0 0
# ANOTHER ITER 35
# PASS RDN25-1+40 2821 0 0
# ANOTHER ITER 35
# PASS RDN25-1+43 2875 0 0
# ANOTHER ITER 35
# PASS RDN25-1+43 2876 0 0
# ANOTHER ITER 35
# PASS RDN25-1+45 2939 0 0
# ANOTHER ITER 35
# PASS RDN25-1+46 2955 0 0
# ANOTHER ITER 35
# PASS RDN18-1+4 207 0 0
# ANOTHER ITER 34
# PASS RDN18-1+10 537 0 0
# ANOTHER ITER 33
# PASS RDN18-1+12 578 0 0
# ANOTHER ITER 32
# PASS RDN18-1+14 627 0 0
# ANOTHER ITER 31
# PASS RDN18-1+19 997 0 0
# ANOTHER ITER 29
# PASS RDN18-1+23 1183 0 0
# ANOTHER ITER 28
# PASS RDN18-1+24 1269 0 0
# ANOTHER ITER 27
# PASS RDN25-1+45 2948 0 0
# ANOTHER ITER 26
# PASS RDN18-1+27 1412 0 0
# ANOTHER ITER 25
# PASS RDN18-1+29 1575 0 0
# ANOTHER ITER 25
# PASS RDN18-1+29 1576 0 0
# ANOTHER ITER 24
# PASS RDN25-1+2 776 0 0
# ANOTHER ITER 23
# PASS RDN25-1+6 871 0 0
# ANOTHER ITER 22
# PASS RDN25-1+7 895 0 0
# ANOTHER ITER 21
# PASS RDN25-1+8 904 0 0
# ANOTHER ITER 20
# PASS RDN25-1+39 2810 0 0
# ANOTHER ITER 20
# PASS RDN25-1+39 2812 0 0
# ANOTHER ITER 19
# PASS RDN25-1+11 990 0 0
# ANOTHER ITER 18
# PASS RDN25-1+14 1050 0 0
# ANOTHER ITER 18
# PASS RDN25-1+22 2142 0 0
# ANOTHER ITER 18
# PASS RDN25-1+34 2635 0 0
# ANOTHER ITER 18
# PASS RDN25-1+16 1122 0 0
# ANOTHER ITER 17
# PASS RDN25-1+19 1444 0 0
# ANOTHER ITER 16
# PASS RDN25-1+20 1888 0 0
# ANOTHER ITER 15
# PASS RDN25-1+21 2133 0 0
# ANOTHER ITER 14
# PASS RDN25-1+25 2215 0 0
# ANOTHER ITER 13
# PASS RDN25-1+26 2252 0 0
# ANOTHER ITER 12
# PASS RDN25-1+27 2281 0 0
# ANOTHER ITER 11
# PASS RDN25-1+28 2284 0 0
# ANOTHER ITER 10
# PASS RDN25-1+29 2310 0 0
# ANOTHER ITER 9
# PASS RDN25-1+33 2619 0 0
# ANOTHER ITER 8
# PASS RDN25-1+35 2640 0 0
# ANOTHER ITER 8
# PASS RDN25-1+45 2940 0 0
# ANOTHER ITER 7
# PASS RDN25-1+35 2641 0 0
# ANOTHER ITER 7
# PASS RDN25-1+35 2642 0 0
# ANOTHER ITER 6
# PASS RDN25-1+36 2719 0 0
# ANOTHER ITER 5
# PASS RDN25-1+37 2735 0 0
# ANOTHER ITER 4
# PASS RDN25-1+40 2822 0 0
# ANOTHER ITER 3
# PASS RDN25-1+43 2877 0 0
# ANOTHER ITER 3
# PASS RDN25-1+43 2878 0 0
# ANOTHER ITER 2
# PASS RDN25-1+42 2867 0 0
# ANOTHER ITER 2
# PASS RDN25-1+42 2868 0 0
# ANOTHER ITER 1
# PASS RDN25-1+46 2956 0 0
# DONE

# %%
kmer_mapping
# Out:
# [['ATACT', ['bTACT', 'aTACT']],
#  ['TATAC', ['TbTAC', 'TaTAC']],
#  ['GTATA', ['GTbTA', 'GTaTA']],
#  ['CGTAT', ['CGTbT', 'CGTaT']],
#  ['TCGTA', ['TCGTa', 'TCGTb']],
#  ['ACTCG', ['aCTCG', 'bCTCG']],
#  ['TACTC', ['TbCTC', 'TaCTC']],
#  ['TTACT', ['TTbCT', 'TTaCT']],
#  ['ATTAC', ['ATTaC', 'ATTbC']],
#  ['AATTA', ['AATTa', 'AATTb']],
#  ['TAAAT', ['aAAAT', 'bAAAT']],
#  ['CTAAA', ['CbAAA', 'CaAAA']],
#  ['ACTAA', ['ACaAA', 'ACbAA']],
#  ['GACTA', ['GACbA', 'GACaA']],
#  ['TGACT', ['TGACb', 'TGACa']],
#  ['TATTT', ['bATTT', 'aATTT']],
#  ['TTATT', ['TbATT', 'TaATT']],
#  ['TTTAT', ['TTbAT', 'TTaAT']],
#  ['GTTTA', ['GTTbA', 'GTTaA']],
#  ['AGTTT', ['AGTTb', 'AGTTa']],
#  ['TATTT', ['aATcc', 'bATcc']],
#  ['TTATT', ['TbATc', 'TaATc']],
#  ['ATTAT', ['ATaAT', 'ATbAT']],
#  ['GATTA', ['GATbA', 'GATaA']],
#  ['AGATT', ['AGATb', 'AGATa']],
#  ['TAAAC', ['aAAAC', 'bAAAC']],
#  ['TTAAA', ['TaAAA', 'TbAAA']],
#  ['TTTAA', ['TTbAA', 'TTaAA']],
#  ['CTTTA', ['CTTaA', 'CTTbA']],
#  ['TCTTT', ['TCTTa', 'TCTTb']],
#  ['CTACA', ['bTACA', 'aTACA']],
#  ['CCTAC', ['CbTAC', 'CaTAC']],
#  ['ACCTA', ['ACbTA', 'ACaTA']],
#  ['AACCT', ['AACbT', 'AACaT']],
#  ['GAACC', ['GAACb', 'GAACa']],
#  ['AGGAA', ['bGGAA', 'aGGAA']],
#  ['AAGGA', ['AbGGA', 'AaGGA']],
#  ['GAAGG', ['GAbGG', 'GAaGG']],
#  ['GGAAG', ['GGAbG', 'GGAaG']],
#  ['CGGAA', ['CGGAb', 'CGGAa']],
#  ['ACGCG', ['bCGCG', 'aCGCG']],
#  ['AACGC', ['AbCGC', 'AaCGC']],
#  ['AAACG', ['AAbCG', 'AAaCG']],
#  ['TAAAC', ['TAAaC', 'TAAbC']],
#  ['TTAAA', ['TTAAa', 'TTAAb']],
#  ['TGATG', ['bGATG', 'aGATG']],
#  ['GTGAT', ['GaGAT', 'GbGAT']],
#  ['AGTGA', ['AGbGA', 'AGaGA']],
#  ['CAGTG', ['CAGbG', 'CAGaG']],
#  ['ACAGT', ['ACAGa', 'ACAGb']],
#  ['AGGAG', ['bGGcG', 'aGGcG']],
#  ['AAGGA', ['AaGGc', 'AbGGc']],
#  ['CAAGG', ['CAaGG', 'CAbGG']],
#  ['ACAAG', ['ACAbG', 'ACAaG']],
#  ['AACAA', ['AACAb', 'AACAa']],
#  ['GGTCT', ['bGTCT', 'aGTCT']],
#  ['TGGTC', ['TaGTC', 'TbGTC']],
#  ['GTGGT', ['GTbGT', 'GTaGT']],
#  ['CGTGG', ['CGTbG', 'CGTaG']],
#  ['CCGTG', ['CCGTa', 'CCGTb']],
#  ['TGGCG', ['aGGCG', 'bGGCG']],
#  ['ATGGC', ['caGGC', 'cbGGC']],
#  ['AATGG', ['AcbGG', 'AcaGG']],
#  ['TAATG', ['TAcaG', 'TAcbG']],
#  ['TTAAT', ['TTAca', 'TTAcb']],
#  ['ATTGA', ['aTTGA', 'bTTGA']],
#  ['AATTG', ['AaTTG', 'AbTTG']],
#  ['AAATT', ['AAaTT', 'AAbTT']],
#  ['AAAAT', ['AAAaT', 'AAAbT']],
#  ['AAAAA', ['AAAAb', 'AAAAa']],
#  ['TGATG', ['aGATc', 'bGATc']],
#  ['TTGAT', ['TbGAT', 'TaGAT']],
#  ['GTTGA', ['GTaGA', 'GTbGA']],
#  ['AGTTG', ['AGTbG', 'AGTaG']],
#  ['AAGTT', ['AAGTb', 'AAGTa']],
#  ['TTAAA', ['bTAAA', 'aTAAA']],
#  ['ATTAA', ['AaTAA', 'AbTAA']],
#  ['GATTA', ['GAaTA', 'GAbTA']],
#  ['AGATT', ['AGAaT', 'AGAbT']],
#  ['GAGAT', ['GAGAb', 'GAGAa']],
#  ['TGTGA', ['aGTGA', 'bGTGA']],
#  ['TTGTG', ['TbGTG', 'TaGTG']],
#  ['CTTGT', ['CTbGT', 'CTaGT']],
#  ['ACTTG', ['ACTaG', 'ACTbG']],
#  ['AACTT', ['AACTa', 'AACTb']],
#  ['ATTAT', ['bTTAT', 'aTTAT']],
#  ['GATTA', ['GaTTA', 'GbTTA']],
#  ['CGATT', ['CGaTT', 'CGbTT']],
#  ['ACGAT', ['ACGbT', 'ACGaT']],
#  ['TACGA', ['TACGa', 'TACGb']],
#  ['AAGAA', ['bAGAA', 'aAGAA']],
#  ['CAAGA', ['CbAGA', 'CaAGA']],
#  ['GCAAG', ['GCaAG', 'GCbAG']],
#  ['AGCAA', ['AGCbA', 'AGCaA']],
#  ['AAGCA', ['AAGCa', 'AAGCb']],
#  ['TAGTA', ['bcGTA', 'acGTA']],
#  ['CTAGT', ['CbcGT', 'CacGT']],
#  ['ACTAG', ['ACacG', 'ACbcG']],
#  ['GACTA', ['GACbc', 'GACac']],
#  ['AGACT', ['AGACb', 'AGACa']],
#  ['CCATA', ['bCATA', 'aCATA']],
#  ['GCCAT', ['GaCAT', 'GbCAT']],
#  ['TGCCA', ['TGaCA', 'TGbCA']],
#  ['CTGCC', ['CTGaC', 'CTGbC']],
#  ['GCTGC', ['GCTGa', 'GCTGb']],
#  ['GAACG', ['aAACG', 'bAACG']],
#  ['GGAAC', ['GbAAC', 'GaAAC']],
#  ['CGGAA', ['CGbAA', 'CGaAA']],
#  ['TCGGA', ['TCGaA', 'TCGbA']],
#  ['GTCGG', ['GTCGb', 'GTCGa']],
#  ['TCGGC', ['bCGGC', 'aCGGC']],
#  ['TTCGG', ['TbCGG', 'TaCGG']],
#  ['ATTCG', ['ATbCG', 'ATaCG']],
#  ['AATTC', ['cATaC', 'cATbC']],
#  ['TAATT', ['TcATa', 'TcATb']],
#  ['TTTAA', ['aTTcA', 'bTTcA']],
#  ['GTTTA', ['GaTTc', 'GbTTc']],
#  ['AGTTT', ['AGbTT', 'AGaTT']],
#  ['CAGTT', ['CAGbT', 'CAGaT']],
#  ['TCAGT', ['bCAGb', 'aCAGa', 'bCAGa', 'aCAGb']],
#  ['TCAGT', ['bCAGb', 'aCAGa', 'bCAGa', 'aCAGb']],
#  ['CTCAG', ['CaCAG', 'CbCAG']],
#  ['ACTCA', ['ACbCA', 'ACaCA']],
#  ['AACTC', ['AACbC', 'AACaC']],
#  ['CAACT', ['CAACa', 'CAACb']],
#  ['TGGTG', ['bGGTG', 'aGGTG']],
#  ['GTGGT', ['cbGGT', 'caGGT']],
#  ['GGTGG', ['bcaGG', 'bcbGG', 'acbGG', 'acaGG']],
#  ['TGGTG', ['TacbG', 'TbcaG', 'TacaG', 'TbcbG']],
#  ['GTGGT', ['GTbca', 'GTacb', 'GTaca', 'GTbcb']],
#  ['GGTGG', ['bcaGG', 'bcbGG', 'acbGG', 'acaGG']],
#  ['TGGTG', ['TacbG', 'TbcaG', 'TacaG', 'TbcbG']],
#  ['GTGGT', ['GTbca', 'GTacb', 'GTaca', 'GTbcb']],
#  ['CGTGG', ['CGTbc', 'CGTac']],
#  ['ACGTG', ['ACGTb', 'ACGTa']],
#  ['CCGGT', ['aCGGT', 'bCGGT']],
#  ['GCCGG', ['GbCGG', 'GaCGG']],
#  ['TGCCG', ['TGaCG', 'TGbCG']],
#  ['TTGCC', ['TTGaC', 'TTGbC']],
#  ['CTTGC', ['CTTGa', 'CTTGb']],
#  ['TTGAT', ['bTGAT', 'aTGAT']],
#  ['GTTGA', ['GbTGA', 'GaTGA']],
#  ['GGTTG', ['GGaTG', 'GGbTG']],
#  ['TGGTT', ['TGGbT', 'TGGaT']],
#  ['GTGGT', ['GTGGb', 'GTGGa']],
#  ['TTTGA', ['bTcGc', 'aTcGc']],
#  ['GTTTG', ['GaTcG', 'GbTcG']],
#  ['AGTTT', ['AGbTc', 'AGaTc']],
#  ['GAGTT', ['GAGaT', 'GAGbT']],
#  ['GGAGT', ['GGAGb', 'GGAGa']],
#  ['GACAA', ['bACAA', 'aACAA']],
#  ['GGACA', ['GbACA', 'GaACA']],
#  ['TGGAC', ['TGaAC', 'TGbAC']],
#  ['CTGGA', ['CTGbA', 'CTGaA']],
#  ['TCTGG', ['TCTGa', 'TCTGb']],
#  ['GCAAC', ['aCAAC', 'bCAAC']],
#  ['AGCAA', ['AbCAA', 'AaCAA']],
#  ['GAGCA', ['cAbCA', 'cAaCA']],
#  ['GGAGC', ['bcAbC', 'acAbC', 'acAaC', 'bcAaC']],
#  ['AGGAG', ['cbcAa', 'cacAa', 'cacAb', 'cbcAb']],
#  ['GGAGC', ['bcAbC', 'acAbC', 'acAaC', 'bcAaC']],
#  ['AGGAG', ['cbcAa', 'cacAa', 'cacAb', 'cbcAb']],
#  ['AAGGA', ['ccacA', 'ccbcA']],
#  ['TAAGG', ['Tccbc', 'Tccac']],
#  ['TTAAG', ['TTcca', 'TTccb']],
#  ['CGCCA', ['bGCCA', 'aGCCA']],
#  ['CCGCC', ['CaGCC', 'CbGCC']],
#  ['CCCGC', ['CCbGC', 'CCaGC']],
#  ['GCCCG', ['GCCaG', 'GCCbG']],
#  ['TGCCC', ['TGCCa', 'TGCCb']],
#  ['CCTTT', ['bCTTT', 'aCTTT']],
#  ['GCCTT', ['GbCTT', 'GaCTT']],
#  ['TGCCT', ['TGbCT', 'TGaCT']],
#  ['ATGCC', ['ATGbC', 'ATGaC']],
#  ['GATGC', ['GATGb', 'GATGa']],
#  ['AGTGG', ['bGTGG', 'aGTGG']],
#  ['AAGTG', ['aaGTG', 'abGTG', 'bbGTG', 'baGTG']],
#  ['CAAGT', ['CabGT', 'CbaGT', 'CaaGT', 'CbbGT']],
#  ['CCAAG', ['CCaaG', 'CCabG', 'CCbaG', 'CCbbG']],
#  ['TCCAA', ['TCCaa', 'TCCbb', 'TCCab', 'TCCba']],
#  ['AAGTG', ['aaGTG', 'abGTG', 'bbGTG', 'baGTG']],
#  ['CAAGT', ['CabGT', 'CbaGT', 'CaaGT', 'CbbGT']],
#  ['CCAAG', ['CCaaG', 'CCabG', 'CCbaG', 'CCbbG']],
#  ['TCCAA', ['TCCaa', 'TCCbb', 'TCCab', 'TCCba']],
#  ['GTCCA', ['GTCCb', 'GTCCa']],
#  ['AGTTC', ['bGTTC', 'aGTTC']],
#  ['AAGTT', ['AaGTT', 'AbGTT']],
#  ['AAAGT', ['AAaGT', 'AAbGT']],
#  ['CAAAG', ['CAAbG', 'CAAaG']],
#  ['ACAAA', ['bCAAa', 'bCAAb', 'aCAAa', 'aCAAb']],
#  ['ACAAA', ['bCAAa', 'bCAAb', 'aCAAa', 'aCAAb']],
#  ['CACAA', ['aaCAA', 'bbCAA', 'abCAA', 'baCAA']],
#  ['GCACA', ['GbaCA', 'GaaCA', 'GabCA', 'GbbCA']],
#  ['GGCAC', ['GGabC', 'GGbaC', 'GGaaC', 'GGbbC']],
#  ['AGGCA', ['AGGab', 'AGGba', 'AGGaa', 'AGGbb']],
#  ['CACAA', ['aaCAA', 'bbCAA', 'abCAA', 'baCAA']],
#  ['GCACA', ['GbaCA', 'GaaCA', 'GabCA', 'GbbCA']],
#  ['GGCAC', ['GGabC', 'GGbaC', 'GGaaC', 'GGbbC']],
#  ['AGGCA', ['AGGab', 'AGGba', 'AGGaa', 'AGGbb']],
#  ['CAGGC', ['CAGGb', 'CAGGa']],
#  ['CTGAG', ['aTGAG', 'bTGAG']],
#  ['TCTGA', ['TbTGA', 'TaTGA']],
#  ['ATCTG', ['ATbTG', 'ATaTG']],
#  ['AATCT', ['AATbT', 'AATaT']],
#  ['CAATC', ['CAATa', 'CAATb']],
#  ['TAGGT', ['bcGGT', 'acGGT']],
#  ['TTAGG', ['cacGG', 'cbcGG']],
#  ['TTTAG', ['TcbcG', 'TcacG']],
#  ['GTTTA', ['GTcac', 'GTcbc']],
#  ['AGTTT', ['AGTca', 'AGTcb']],
#  ['GCCCA', ['bCCCA', 'aCCCA']],
#  ['AGCCC', ['AaCCC', 'AbCCC']],
#  ['AAGCC', ['aAaCC', 'aAbCC', 'bAbCC', 'bAaCC']],
#  ['AAAGC', ['AaAbC', 'AaAaC', 'AbAaC', 'AbAbC']],
#  ['GAAAG', ['GAbAa', 'GAaAb', 'GAbAb', 'GAaAa']],
#  ['AAGCC', ['aAaCC', 'aAbCC', 'bAbCC', 'bAaCC']],
#  ['AAAGC', ['AaAbC', 'AaAaC', 'AbAaC', 'AbAbC']],
#  ['GAAAG', ['GAbAa', 'GAaAb', 'GAbAb', 'GAaAa']],
#  ['AGAAA', ['AGAaA', 'AGAbA']],
#  ['TAGAA', ['TAGAb', 'TAGAa']],
#  ['AAGTG', ['aAGTG', 'bAGTG']],
#  ['CAAGT', ['CbAGT', 'CaAGT']],
#  ['TCAAG', ['TCaAG', 'TCbAG']],
#  ['ATCAA', ['ATCbA', 'ATCaA']],
#  ['TATCA', ['TATCb', 'TATCa']],
#  ['GATGC', ['bATGC', 'aATGC']],
#  ['CGATG', ['CbATG', 'CaATG']],
#  ['GCGAT', ['GCbAT', 'GCaAT']],
#  ['GGCGA', ['GGCbA', 'GGCaA']],
#  ['TGGCG', ['TGGCa', 'TGGCb']],
#  ['AGTCT', ['aGTCc', 'bGTCc']],
#  ['CAGTC', ['CaGTC', 'CbGTC']],
#  ['GCAGT', ['GCbGT', 'GCaGT']],
#  ['TGCAG', ['TGCbG', 'TGCaG']],
#  ['GTGCA', ['GTGCa', 'GTGCb']],
#  ['TTAAG', ['bTcAG', 'aTcAG']],
#  ['TTTAA', ['TaTcA', 'TbTcA']],
#  ['GTTTA', ['GTbTc', 'GTaTc']],
#  ['GGTTT', ['GGTbT', 'GGTaT']],
#  ['GGGTT', ['GGGTb', 'GGGTa']],
#  ['GGATA', ['bGAcA', 'aGAcA']],
#  ['GGGAT', ['GbGAc', 'GaGAc']],
#  ['GGGGA', ['GGaGA', 'GGbGA']],
#  ['CGGGG', ['CGGaG', 'CGGbG']],
#  ['GCGGG', ['GCGGa', 'GCGGb']],
#  ['TCCCT', ['bCCCT', 'aCCCT']],
#  ['CTCCC', ['CaCCC', 'CbCCC']],
#  ['ACTCC', ['ACbCC', 'ACaCC']],
#  ['GACTC', ['GACbC', 'GACaC']],
#  ['GGACT', ['GGACa', 'GGACb']],
#  ['TAGGA', ['bAGGA', 'aAGGA']],
#  ['ATAGG', ['AbAGG', 'AaAGG']],
#  ['GATAG', ['GAbAG', 'GAaAG']],
#  ['CGATA', ['CGAaA', 'CGAbA']],
#  ['ACGAT', ['ACGAb', 'ACGAa']],
#  ['TTGAC', ['aTGcC', 'bTGcC']],
#  ['TTTGA', ['TaTGc', 'TbTGc']],
#  ['TTTTG', ['TTaTG', 'TTbTG']],
#  ['ATTTT', ['ATTbT', 'ATTaT']],
#  ['TATTT', ['bATTb', 'aATTb', 'bATTa', 'aATTa']],
#  ['TATTT', ['bATTb', 'aATTb', 'bATTa', 'aATTa']],
#  ['GTATT', ['cbATT', 'caATT']],
#  ['AGTAT', ['AcbAT', 'AcaAT']],
#  ['GAGTA', ['GAcaA', 'GAcbA']],
#  ['GGAGT', ['GGAca', 'GGAcb']],
#  ['TAAGC', ['aAAGC', 'bAAGC']],
#  ['GTAAG', ['GaAAG', 'GbAAG']],
#  ['AGTAA', ['AGbAA', 'AGaAA']],
#  ['TAGTA', ['TAGaA', 'TAGbA']],
#  ['TTAGT', ['TTAGb', 'TTAGa']],
#  ['TTATC', ['aTATC', 'bTATC']],
#  ['CTTAT', ['CaTAT', 'CbTAT']],
#  ['TCTTA', ['TCaTA', 'TCbTA']],
#  ['CTCTT', ['CTCaT', 'CTCbT']],
#  ['ACTCT', ['ACTCa', 'ACTCb']],
#  ['TTTCA', ['bccCA', 'accCA']],
#  ['ATTTC', ['AbccC', 'AaccC']],
#  ['AATTT', ['AAacc', 'AAbcc']],
#  ['AAATT', ['AAAac', 'AAAbc']],
#  ['TAAAT', ['bAAAa', 'aAAAb', 'aAAAa', 'bAAAb']],
#  ['TAAAT', ['bAAAa', 'aAAAb', 'aAAAa', 'bAAAb']],
#  ['ATAAA', ['AbAAA', 'AaAAA']],
#  ['TATAA', ['TAaAA', 'TAbAA']],
#  ['GTATA', ['GTAaA', 'GTAbA']],
#  ['TGTAT', ['TGTAb', 'TGTAa']],
#  ['TTTCG', ['aTTCG', 'bTTCG']],
#  ['TTTTC', ['TbTTC', 'TaTTC']],
#  ['ATTTT', ['ATbTT', 'ATaTT']],
#  ['GATTT', ['GATaT', 'GATbT']],
#  ['TGATT', ['TGATb', 'TGATa']],
#  ['TTTTA', ['acTTA', 'bcTTA']],
#  ['TTTTT', ['TbcTT', 'TacTT']],
#  ['GTTTT', ['GTbcT', 'GTacT']],
#  ['GGTTT', ['GGTbc', 'GGTac']],
#  ['TGGTT', ['TGGTb', 'TGGTa']],
#  ['ACGAA', ['bCGAA', 'aCGAA']],
#  ['GACGA', ['GaCGA', 'GbCGA']],
#  ['AGACG', ['AGbCG', 'AGaCG']],
#  ['AAGAC', ['AAGbC', 'AAGaC']],
#  ['CAAGA', ['CAAGb', 'CAAGa']],
#  ['CTAGA', ['aTAGA', 'bTAGA']],
#  ['TCTAG', ['TbTAG', 'TaTAG']],
#  ['TTCTA', ['TTbTA', 'TTaTA']],
#  ['GTTCT', ['GTTaT', 'GTTbT']],
#  ['GGTTC', ['GGTTa', 'GGTTb']],
#  ['ATGAT', ['aTGAc', 'bTGAc']],
#  ['GATGA', ['abTGA', 'bbTGA', 'baTGA', 'aaTGA']],
#  ['CGATG', ['CaaTG', 'CbbTG', 'CbaTG', 'CabTG']],
#  ['ACGAT', ['ACbbT', 'ACaaT', 'ACbaT', 'ACabT']],
#  ['AACGA', ['AACaa', 'AACba', 'AACbb', 'AACab']],
#  ['GATGA', ['abTGA', 'bbTGA', 'baTGA', 'aaTGA']],
#  ['CGATG', ['CaaTG', 'CbbTG', 'CbaTG', 'CabTG']],
#  ['ACGAT', ['ACbbT', 'ACaaT', 'ACbaT', 'ACabT']],
#  ['AACGA', ['AACaa', 'AACba', 'AACbb', 'AACab']],
#  ['AAACG', ['AAACb', 'AAACa']],
#  ['TAATA', ['bAATA', 'aAATA']],
#  ['GTAAT', ['cbAAT', 'caAAT']],
#  ['TGTAA', ['TcaAA', 'TcbAA']],
#  ['ATGTA', ['ATcaA', 'ATcbA']],
#  ['GATGT', ['GATcb', 'GATca']],
#  ['TCTAA', ['bCTAA', 'aCTAA']],
#  ['GTCTA', ['cbCTA', 'caCTA']],
#  ['AGTCT', ['ccaCT', 'ccbCT']],
#  ['CAGTC', ['cccbC', 'cccaC']],
#  ['TCAGT', ['accca', 'acccb', 'bcccb', 'bccca']],
#  ['TCAGT', ['accca', 'acccb', 'bcccb', 'bccca']],
#  ['GTCAG', ['cbccc', 'caccc']],
#  ['TGTCA', ['Tcacc', 'Tcbcc']],
#  ['CTGTC', ['CTcbc', 'CTcac']],
#  ['TCTGT', ['TCTcb', 'TCTca']],
#  ['ATTAA', ['accAc', 'bccAc']],
#  ['AATTA', ['caccA', 'cbccA']],
#  ['AAATT', ['Acacc', 'Acbcc']],
#  ['AAAAT', ['AAcac', 'AAcbc']],
#  ['CAAAA', ['CAAca', 'CAAcb']],
#  ['TTTAG', ['aTTAG', 'bTTAG']],
#  ['CTTTA', ['CbTTA', 'CaTTA']],
#  ['TCTTT', ['TCaTT', 'TCbTT']],
#  ['GTCTT', ['GTCaT', 'GTCbT']],
#  ['CGTCT', ['CGTCa', 'CGTCb']],
#  ['CCCGT', ['aCCGT', 'bCCGT']],
#  ['ACCCG', ['AaCCG', 'AbCCG']],
#  ['GACCC', ['GAaCC', 'GAbCC']],
#  ['TGACC', ['TGAbC', 'TGAaC']],
#  ['GTGAC', ['GTGAa', 'GTGAb']],
#  ['AAGTG', ['bAGTc', 'aAGTc']],
#  ['GAAGT', ['GaAGT', 'GbAGT']],
#  ['AGAAG', ['AGaAG', 'AGbAG']],
#  ['AAGAA', ['AAGbA', 'AAGaA']],
#  ['AAAGA', ['AAAGa', 'AAAGb']],
#  ['AATGA', ['bATcA', 'aATcA']],
#  ['CAATG', ['CbATc', 'CaATc']],
#  ['TCAAT', ['aCbAT', 'aCaAT', 'bCbAT', 'bCaAT']],
#  ['ATCAA', ['AaCbA', 'AbCaA', 'AbCbA', 'AaCaA']],
#  ['TATCA',
#   ['bAbCa', 'bAbCb', 'aAaCb', 'aAbCa', 'aAbCb', 'bAaCa', 'aAaCa', 'bAaCb']],
#  ['TCAAT', ['aCbAT', 'aCaAT', 'bCbAT', 'bCaAT']],
#  ['ATCAA', ['AaCbA', 'AbCaA', 'AbCbA', 'AaCaA']],
#  ['TATCA',
#   ['bAbCa', 'bAbCb', 'aAaCb', 'aAbCa', 'aAbCb', 'bAaCa', 'aAaCa', 'bAaCb']],
#  ['GTATC', ['cbAaC', 'cbAbC', 'caAaC', 'caAbC']],
#  ['AGTAT', ['AcaAb', 'AcbAa', 'AcaAa', 'AcbAb']],
#  ['TATCA',
#   ['bAbCa', 'bAbCb', 'aAaCb', 'aAbCa', 'aAbCb', 'bAaCa', 'aAaCa', 'bAaCb']],
#  ['GTATC', ['cbAaC', 'cbAbC', 'caAaC', 'caAbC']],
#  ['AGTAT', ['AcaAb', 'AcbAa', 'AcaAa', 'AcbAb']],
#  ['CAGTA', ['CAcbA', 'CAcaA']],
#  ['TCAGT', ['aCAcb', 'bCAcb', 'aCAca', 'bCAca']],
#  ['TCAGT', ['aCAcb', 'bCAcb', 'aCAca', 'bCAca']],
#  ['CTCAG', ['CbCAc', 'CaCAc']],
#  ['TCTCA', ['bCaCA', 'bCbCA', 'aCaCA', 'aCbCA']],
#  ['CTCTC', ['CaCaC', 'CbCbC', 'CaCbC', 'CbCaC']],
#  ['TCTCT', ['TCbCa', 'TCbCb', 'TCaCb', 'TCaCa']],
#  ['TCTCA', ['bCaCA', 'bCbCA', 'aCaCA', 'aCbCA']],
#  ['CTCTC', ['CaCaC', 'CbCbC', 'CaCbC', 'CbCaC']],
#  ['TCTCT', ['TCbCa', 'TCbCb', 'TCaCb', 'TCaCa']],
#  ['TTCTC', ['TTCbC', 'TTCaC']],
#  ['ATTCT', ['ATTCa', 'ATTCb']],
#  ['CCGAT', ['aCGAT', 'bCGAT']],
#  ['ACCGA', ['AaCGA', 'AbCGA']],
#  ['AACCG', ['aAbCG', 'aAaCG', 'bAbCG', 'bAaCG']],
#  ['AAACC',
#   ['bbAbC', 'aaAbC', 'abAaC', 'baAaC', 'bbAaC', 'aaAaC', 'baAbC', 'abAbC']],
#  ['TAAAC',
#   ['cbbAa', 'cabAa', 'caaAa', 'cbbAb', 'cabAb', 'cbaAb', 'caaAb', 'cbaAa']],
#  ['AACCG', ['aAbCG', 'aAaCG', 'bAbCG', 'bAaCG']],
#  ['AAACC',
#   ['bbAbC', 'aaAbC', 'abAaC', 'baAaC', 'bbAaC', 'aaAaC', 'baAbC', 'abAbC']],
#  ['TAAAC',
#   ['cbbAa', 'cabAa', 'caaAa', 'cbbAb', 'cabAb', 'cbaAb', 'caaAb', 'cbaAa']],
#  ['GTAAA', ['GcabA', 'GcbaA', 'GcaaA', 'GcbbA']],
#  ['CGTAA', ['CGcaa', 'CGcbb', 'CGcba', 'CGcab']],
#  ['AAACC',
#   ['bbAbC', 'aaAbC', 'abAaC', 'baAaC', 'bbAaC', 'aaAaC', 'baAbC', 'abAbC']],
#  ['TAAAC',
#   ['cbbAa', 'cabAa', 'caaAa', 'cbbAb', 'cabAb', 'cbaAb', 'caaAb', 'cbaAa']],
#  ['GTAAA', ['GcabA', 'GcbaA', 'GcaaA', 'GcbbA']],
#  ['CGTAA', ['CGcaa', 'CGcbb', 'CGcba', 'CGcab']],
#  ['CCGTA', ['cCGca', 'cCGcb']],
#  ['GCTCC', ['aCTcC', 'bCTcC']],
#  ['TGCTC', ['TbCTc', 'TaCTc']],
#  ['CTGCT', ['CTbCT', 'CTaCT']],
#  ['ACTGC', ['ACTaC', 'ACTbC']],
#  ['TACTG', ['TACTb', 'TACTa']],
#  ['TAAGT', ['aAAcT', 'bAAcT']],
#  ['GTAAG', ['GbAAc', 'GaAAc']],
#  ['GGTAA', ['GGaAA', 'GGbAA']],
#  ['AGGTA', ['AGGaA', 'AGGbA']],
#  ['TAGGT', ['TAGGb', 'TAGGa']],
#  ['CTGTC', ['bTGTC', 'aTGTC']],
#  ['CCTGT', ['CbTGT', 'CaTGT']],
#  ['CCCTG', ['CCbTG', 'CCaTG']],
#  ['TCCCT', ['aCCaT', 'bCCaT', 'aCCbT', 'bCCbT']],
#  ['ATCCC', ['AbCCb', 'AbCCa', 'AaCCa', 'AaCCb']],
#  ['TCCCT', ['aCCaT', 'bCCaT', 'aCCbT', 'bCCbT']],
#  ['ATCCC', ['AbCCb', 'AbCCa', 'AaCCa', 'AaCCb']],
#  ['TATCC', ['TAbCC', 'TAaCC']],
#  ['CTATC', ['CTAbC', 'CTAaC']],
#  ['TCTAT', ['TCTAb', 'TCTAa']],
#  ['TCATC', ['aCATC', 'bCATC']],
#  ['ATCAT', ['cbCAT', 'caCAT']],
#  ['TATCA', ['acaCA', 'acbCA', 'bcbCA', 'bcaCA']],
#  ['CTATC', ['CacbC', 'CacaC', 'CbcaC', 'CbcbC']],
#  ['TCTAT',
#   ['aCacb', 'bCbcb', 'bCaca', 'bCbca', 'bCacb', 'aCaca', 'aCbca', 'aCbcb']],
#  ['TATCA', ['acaCA', 'acbCA', 'bcbCA', 'bcaCA']],
#  ['CTATC', ['CacbC', 'CacaC', 'CbcaC', 'CbcbC']],
#  ['TCTAT',
#   ['aCacb', 'bCbcb', 'bCaca', 'bCbca', 'bCacb', 'aCaca', 'aCbca', 'aCbcb']],
#  ['ATCTA', ['AaCac', 'AaCbc', 'AbCbc', 'AbCac']],
#  ['GATCT', ['GAbCb', 'GAaCa', 'GAaCb', 'GAbCa']],
#  ['TCTAT',
#   ['aCacb', 'bCbcb', 'bCaca', 'bCbca', 'bCacb', 'aCaca', 'aCbca', 'aCbcb']],
#  ['ATCTA', ['AaCac', 'AaCbc', 'AbCbc', 'AbCac']],
#  ['GATCT', ['GAbCb', 'GAaCa', 'GAaCb', 'GAbCa']],
#  ['CGATC', ['CGAbC', 'CGAaC']],
#  ['GCGAT', ['GCGAa', 'GCGAb']],
#  ['TCGAG', ['aCGAG', 'bCGAG']],
#  ['TTCGA', ['bbCGA', 'abCGA', 'aaCGA', 'baCGA']],
#  ['GTTCG', ['caaCG', 'cbaCG', 'cabCG', 'cbbCG']],
#  ['AGTTC', ['ccabC', 'ccbaC', 'ccbbC', 'ccaaC']],
#  ['CAGTT', ['Cccab', 'Cccbb', 'Cccba', 'Cccaa']],
#  ['TTCGA', ['bbCGA', 'abCGA', 'aaCGA', 'baCGA']],
#  ['GTTCG', ['caaCG', 'cbaCG', 'cabCG', 'cbbCG']],
#  ['AGTTC', ['ccabC', 'ccbaC', 'ccbbC', 'ccaaC']],
#  ['CAGTT', ['Cccab', 'Cccbb', 'Cccba', 'Cccaa']],
#  ['TCAGT', ['bCccb', 'aCccb', 'bCcca', 'aCcca']],
#  ['TCAGT', ['bCccb', 'aCccb', 'bCcca', 'aCcca']],
#  ['CTCAG', ['CaCcc', 'CbCcc']],
#  ['TCTCA', ['TCbCc', 'TCaCc']],
#  ['ATCTC', ['ATCbC', 'ATCaC']],
#  ['GATCT', ['GATCb', 'GATCa']],
#  ['GGTCG', ['bcTCG', 'acTCG']],
#  ['GGGTC', ['cbcTC', 'cacTC']],
#  ['GGGGT', ['GcacT', 'GcbcT']],
#  ['CGGGG', ['CGcac', 'CGcbc']],
#  ['GCGGG', ['GCGca', 'GCGcb']],
#  ['TTGTC', ['acGTc', 'bcGTc']],
#  ['ATTGT', ['cacGT', 'cbcGT']],
#  ['AATTG', ['ccbcG', 'ccacG']],
#  ['AAATT', ['Accac', 'Accbc']],
#  ['CAAAT', ['CAccb', 'CAcca']],
#  ['AGCAA', ['bGCAc', 'aGCAc']],
#  ['TAGCA', ['caGCA', 'cbGCA']],
#  ['ATAGC', ['ccaGC', 'ccbGC']],
#  ['AATAG', ['cccaG', 'cccbG']],
#  ['CAATA', ['Ccccb', 'Cccca']],
#  ['TTTAG', ['bTTAc', 'aTTAc']],
#  ['TTTTA', ['TaTTA', 'TbTTA']],
#  ['CTTTT', ['CTaTT', 'CTbTT']],
#  ['ACTTT', ['ACTbT', 'ACTaT']],
#  ['GACTT', ['GACTb', 'GACTa']],
#  ['TGACT', ['aGACT', 'bGACT']],
#  ['GTGAC', ['GbGAC', 'GaGAC']],
#  ['TGTGA', ['cGaGA', 'cGbGA']],
#  ['GTGTG', ['GcGbG', 'GcGaG']],
#  ['AGTGT', ['AGcGa', 'AGcGb']],
#  ['TAAGT', ['bAAGc', 'aAAGc']],
#  ['ATAAG', ['caAAG', 'cbAAG']],
#  ['CATAA', ['CcaAA', 'CcbAA']],
#  ['ACATA', ['ACcbA', 'ACcaA']],
#  ['AACAT', ['AACcb', 'AACca']],
#  ['GATCG', ['bATCG', 'aATCG']],
#  ['AGATC', ['AaATC', 'AbATC']],
#  ['GAGAT', ['aAbAT', 'aAaAT', 'bAbAT', 'bAaAT']],
#  ['GGAGA', ['GaAaA', 'GbAaA', 'GaAbA', 'GbAbA']],
#  ['TGGAG', ['TGbAa', 'TGaAa', 'TGbAb', 'TGaAb']],
#  ['GAGAT', ['aAbAT', 'aAaAT', 'bAbAT', 'bAaAT']],
#  ['GGAGA', ['GaAaA', 'GbAaA', 'GaAbA', 'GbAbA']],
#  ['TGGAG', ['TGbAa', 'TGaAa', 'TGbAb', 'TGaAb']],
#  ['GTGGA', ['GTGbA', 'GTGaA']],
#  ['CGTGG', ['CGTGb', 'CGTGa']],
#  ['GGACA', ['aGccc', 'bGccc']],
#  ['GGGAC', ['GaGcc', 'GbGcc']],
#  ['AGGGA', ['AGbGc', 'AGaGc']],
#  ['TAGGG', ['TAGbG', 'TAGaG']],
#  ['ATAGG', ['ATAGb', 'ATAGa']],
#  ['TCGGT', ['aCGcc', 'bCGcc']],
#  ['TTCGG', ['TaCGc', 'TbCGc']],
#  ['GTTCG', ['GTbCG', 'GTaCG']],
#  ['TGTTC', ['TGTbC', 'TGTaC']],
#  ['GTGTT', ['GTGTa', 'GTGTb']],
#  ['TTGCG', ['aTGCG', 'bTGCG']],
#  ['CTTGC', ['CbTGC', 'CaTGC']],
#  ['ACTTG', ['ACbTG', 'ACaTG']],
#  ['TACTT', ['TACaT', 'TACbT']],
#  ['ATACT', ['ATACa', 'ATACb']],
#  ['TAGTT', ['bAGTT', 'aAGTT']],
#  ['TTAGT', ['TbAGT', 'TaAGT']],
#  ['CTTAG', ['CTbAG', 'CTaAG']],
#  ['TCTTA', ['cCTbA', 'cCTaA']],
#  ['TTCTT', ['ccCTa', 'ccCTb']],
#  ['CTTCT', ['bccCT', 'accCT']],
#  ['GCTTC', ['GaccC', 'GbccC']],
#  ['AGCTT', ['AGacc', 'AGbcc']],
#  ['TAGCT', ['TAGbc', 'TAGac']],
#  ['GTAGC', ['GTAGa', 'GTAGb']],
#  ['TCGGC', ['acccc', 'bcccc']],
#  ['CTCGG', ['Caccc', 'Cbccc']],
#  ['TCTCG', ['TCacc', 'TCbcc']],
#  ['TTCTC', ['TTCac', 'TTCbc']],
#  ['CTTCT', ['CTTCa', 'CTTCb']],
#  ['TTAGG', ['aTAGG', 'bTAGG']],
#  ['GTTAG', ['bbTAG', 'abTAG', 'aaTAG', 'baTAG']],
#  ['TGTTA',
#   ['abaTA', 'aaaTA', 'baaTA', 'bbaTA', 'babTA', 'bbbTA', 'aabTA', 'abbTA']],
#  ['TTGTT',
#   ['TbabT', 'TabaT', 'TaabT', 'TabbT', 'TbbbT', 'TaaaT', 'TbaaT', 'TbbaT']],
#  ['CTTGT',
#   ['CTbba', 'CTbaa', 'CTabb', 'CTbab', 'CTbbb', 'CTaba', 'CTaaa', 'CTaab']],
#  ['GTTAG', ['bbTAG', 'abTAG', 'aaTAG', 'baTAG']],
#  ['TGTTA',
#   ['abaTA', 'aaaTA', 'baaTA', 'bbaTA', 'babTA', 'bbbTA', 'aabTA', 'abbTA']],
#  ['TTGTT',
#   ['TbabT', 'TabaT', 'TaabT', 'TabbT', 'TbbbT', 'TaaaT', 'TbaaT', 'TbbaT']],
#  ['CTTGT',
#   ['CTbba', 'CTbaa', 'CTabb', 'CTbab', 'CTbbb', 'CTaba', 'CTaaa', 'CTaab']],
#  ['ACTTG', ['ACTab', 'ACTba', 'ACTaa', 'ACTbb']],
#  ['TGTTA',
#   ['abaTA', 'aaaTA', 'baaTA', 'bbaTA', 'babTA', 'bbbTA', 'aabTA', 'abbTA']],
#  ['TTGTT',
#   ['TbabT', 'TabaT', 'TaabT', 'TabbT', 'TbbbT', 'TaaaT', 'TbaaT', 'TbbaT']],
#  ['CTTGT',
#   ['CTbba', 'CTbaa', 'CTabb', 'CTbab', 'CTbbb', 'CTaba', 'CTaaa', 'CTaab']],
#  ['ACTTG', ['ACTab', 'ACTba', 'ACTaa', 'ACTbb']],
#  ['CACTT', ['CACTb', 'CACTa']],
#  ['TGCAA', ['aGCcc', 'bGCcc']],
#  ['GTGCA', ['caGCc', 'cbGCc']],
#  ['AGTGC', ['acaGC', 'bcbGC', 'bcaGC', 'acbGC']],
#  ['GAGTG', ['cbcaG', 'cbcbG', 'cacbG', 'cacaG']],
#  ['CGAGT',
#   ['acbcb', 'bcacb', 'acaca', 'bcaca', 'bcbcb', 'acacb', 'bcbca', 'acbca']],
#  ['AGTGC', ['acaGC', 'bcbGC', 'bcaGC', 'acbGC']],
#  ['GAGTG', ['cbcaG', 'cbcbG', 'cacbG', 'cacaG']],
#  ['CGAGT',
#   ['acbcb', 'bcacb', 'acaca', 'bcaca', 'bcbcb', 'acacb', 'bcbca', 'acbca']],
#  ['TCGAG', ['cacac', 'cbcbc', 'cacbc', 'cbcac']],
#  ['GTCGA', ['Gcbcb', 'Gcaca', 'Gcacb', 'Gcbca']],
#  ['CGAGT',
#   ['acbcb', 'bcacb', 'acaca', 'bcaca', 'bcbcb', 'acacb', 'bcbca', 'acbca']],
#  ['TCGAG', ['cacac', 'cbcbc', 'cacbc', 'cbcac']],
#  ['GTCGA', ['Gcbcb', 'Gcaca', 'Gcacb', 'Gcbca']],
#  ['GGTCG', ['GGcac', 'GGcbc']],
#  ['GGGTC', ['GGGca', 'GGGcb']],
#  ['CAGAT', ['aAccT', 'bAccT']],
#  ['CCAGA', ['CbAcc', 'CaAcc']],
#  ['GCCAG', ['GCaAc', 'GCbAc']],
#  ['TGCCA', ['TGCaA', 'TGCbA']],
#  ['CTGCC', ['CTGCa', 'CTGCb']],
#  ['TTGGA', ['aTGGA', 'bTGGA']],
#  ['ATTGG', ['AaTGG', 'AbTGG']],
#  ['GATTG', ['GAbTG', 'GAaTG']],
#  ['TGATT', ['TGAbT', 'TGAaT']],
#  ['TTGAT', ['TTGAb', 'TTGAa']]]
